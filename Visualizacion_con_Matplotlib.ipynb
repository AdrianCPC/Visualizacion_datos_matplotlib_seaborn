# %% [markdown]
# <a href="https://colab.research.google.com/github/AdrianCPC/Visualizacion_datos_matplotlib_seaborn/blob/main/Visualizacion_con_Matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Analisis 01

# %% [markdown]
# ##Primeras Visualizaciones

# %%
import pandas as pd

df = pd.read_csv('base_tiempo.csv')
df.head()
# Out:
#    temperatura  presión  humedad  dirección del viento  velocidad del viento  \
# 0   282.080000   1024.0     81.0                   0.0                   0.0
# 1   282.080000   1024.0     81.0                   0.0                   0.0
# 2   282.083252   1024.0     80.0                   4.0                   0.0
# 3   282.091866   1024.0     80.0                  18.0                   0.0
# 4   282.100481   1024.0     80.0                  31.0                   0.0
#
#   dia_de_semana                fecha
# 0       Domingo  2012-10-01 12:00:00
# 1       Domingo  2012-10-01 13:00:00
# 2       Domingo  2012-10-01 14:00:00
# 3       Domingo  2012-10-01 15:00:00
# 4       Domingo  2012-10-01 16:00:00

# %% [markdown]
# Transformacion de las fechas a formato correcto

# %%
df['date'] = pd.to_datetime(df['fecha'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45253 entries, 0 to 45252
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   temperatura           45253 non-null  float64
#  1   presión               45253 non-null  float64
#  2   humedad               45253 non-null  float64
#  3   dirección del viento  45253 non-null  float64
#  4   velocidad del viento  45253 non-null  float64
#  5   dia_de_semana         45253 non-null  object
#  6   fecha                 45253 non-null  object
#  7   date                  45253 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(5), object(2)
# memory usage: 2.8+ MB

# %% [markdown]
# Usando los graficos de matplotlib

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.plot(df['date'], df['temperatura']);

# %%
plt.figure(figsize=(15,8))
plt.plot(df['date'], df['temperatura']); #temp en grados kelvin

# %%
plt.figure(figsize=(15,8))
plt.plot(df['date'], df['temperatura']);
plt.title('Temperatura en el tiempo');

# %%
fig = plt.figure(figsize=(15,8))
eje = fig.add_axes([0,0,1,1]);

# %%
fig = plt.figure(figsize=(15,8))
eje = fig.add_axes([0,0,1,1]);
eje.plot(df['date'], df['temperatura']);
eje.set_title('Temperatura en el tiempo');

# %%
fig = plt.figure(figsize=(15,8))
eje = fig.add_axes([0,0,1,1]);
eje.plot(df['date'], df['temperatura']);
eje.set_title('Temperatura en el tiempo');
eje.set_ylabel('Temperatura');
eje.set_xlabel('Date');

# %%
fig = plt.figure(figsize=(15,8))
eje = fig.add_axes([0,0,1,1]);
eje.plot(df['date'], df['temperatura']);
eje.set_title('Temperatura en el tiempo', fontsize=25);
eje.set_ylabel('Temperatura', fontsize=20);
eje.set_xlabel('Date', fontsize=20);

# %%
fig = plt.figure(figsize=(15,8))
eje = fig.add_axes([0,0,1,1]);
eje.plot(df['date'], df['temperatura']);
eje.set_title('Temperatura en el tiempo');
eje.set_ylabel('Temperatura');
eje.set_xlabel('Date');
eje.legend(['temperatura'], loc='lower right', fontsize=15);

# %%
fig = plt.figure(figsize=(15,8))
eje = fig.add_axes([0,0,1,1]);
eje.plot(df['date'], df['temperatura'], color='green');
eje.set_title('Temperatura en el tiempo');
eje.set_ylabel('Temperatura');
eje.set_xlabel('Date');
eje.legend(['temperatura'], loc='lower right', fontsize=15);

# %% [markdown]
# En esta aula, aprendimos:
#
# Importación de bibliotecas;
#
# Lectura de datos;
#
# Conversión para datetime;
#
# Gráfico de línea;
#
# Colocar título en el gráfico;
#
# Crear objetos de tipo figura y eje;
#
# Crear gráficos utilizando el objeto eje;
#
# Colocar título en el eje;
#
# Colocar un nombre en los ejes x e y;
#
# Cambie el tamaño de las fuentes en el gráfico;
#
# Cambia el color de las líneas del gráfico.

# %% [markdown]
# #Analisis 02

# %% [markdown]
# ##Personalizando nuestras visualizaciones

# %%
fig = plt.figure(figsize=(15,8))
eje = fig.add_axes([0,0,1,1]);
eje.plot(df['date'], df['temperatura'], color='g', lw=0.4);
eje.set_title('Temperatura en el tiempo');
eje.set_ylabel('Temperatura');
eje.set_xlabel('Date');
eje.legend(['temperatura'], loc='lower right', fontsize=15);

# %%
fig = plt.figure(figsize=(15,8))
eje = fig.add_axes([0,0,1,1]);
eje.plot(df['date'], df['temperatura'], color='g', ls='dotted');
eje.set_title('Temperatura en el tiempo');
eje.set_ylabel('Temperatura');
eje.set_xlabel('Date');
eje.legend(['temperatura'], loc='lower right', fontsize=15);

# %%
import datetime

fig = plt.figure(figsize=(15,8))
eje = fig.add_axes([0,0,1,1]);
eje.plot(df['date'], df['temperatura'], color='g');
eje.set_xlim(datetime.datetime(2014,1,1),datetime.datetime(2015,1,1))
eje.set_title('Temperatura en el tiempo');
eje.set_ylabel('Temperatura');
eje.set_xlabel('Date');
eje.legend(['temperatura'], loc='lower right', fontsize=15);

# %%
fig = plt.figure(figsize=(15,8))
eje = fig.add_axes([0,0,1,1]);
eje.plot(df['date'], df['temperatura'], color='g', marker ='o');
eje.set_xlim(datetime.datetime(2014,1,1),datetime.datetime(2015,1,1))
eje.set_title('Temperatura en el tiempo');
eje.set_ylabel('Temperatura');
eje.set_xlabel('Date');
eje.legend(['temperatura'], loc='lower right', fontsize=15);

# %%
fig = plt.figure(figsize=(15,8))
eje = fig.add_axes([0,0,1,1]);
eje.plot(df['date'], df['temperatura'], color='g');
eje.set_xlim(datetime.datetime(2014,1,1),datetime.datetime(2015,1,1))
eje.set_title('Temperatura en el tiempo');
eje.set_ylabel('Temperatura');
eje.set_xlabel('Date');
eje.legend(['temperatura'], loc='lower right', fontsize=15);
eje.grid(True)

# %%
fig = plt.figure(figsize=(15,8))
eje = fig.add_axes([0,0,1,1]);
eje2 = fig.add_axes([0.1,0.5,0.4,0.4])

# %%
fig = plt.figure(figsize=(15,8))
eje = fig.add_axes([0,0,1,1]);
eje2 = fig.add_axes([0.1,0.5,0.4,0.4])
eje.grid(True)
eje.plot(df['date'], df['temperatura'], color='g');
eje.set_title('Temperatura en el tiempo', fontsize=25, pad=20);
eje.legend(['temperatura'], loc='best', fontsize=15);

# %%
fig = plt.figure(figsize=(15,8))
eje = fig.add_axes([0,0,1,1]);
eje2 = fig.add_axes([0.1,0.5,0.4,0.4])
eje.grid(True)
eje.plot(df['date'], df['temperatura'], color='g');
eje.set_title('Temperatura en el tiempo', fontsize=25, pad=20);
eje.legend(['temperatura'], loc='best', fontsize=15);
eje.set_ylabel('Temperatura', fontsize=20);
eje.set_xlabel('Date', fontsize=20);


eje2.plot(df['date'], df['temperatura'], color='b');
eje2.set_title('Temperatura en el tiempo', fontsize=15);
eje2.legend(['temperatura'], loc='best', fontsize=8);
eje2.set_ylabel('Temperatura', fontsize=10);
eje2.set_xlabel('Date', fontsize=10);

# %%
fig = plt.figure(figsize=(15,8))
eje = fig.add_axes([0,0,1,1]);
eje2 = fig.add_axes([0.7,0.65,0.3,0.3])
eje.grid(True)
eje.plot(df['date'], df['temperatura'], color='g');
eje.set_xlim(datetime.datetime(2014,1,1),datetime.datetime(2015,1,1))
eje.set_title('Temperatura en 2014', fontsize=25, pad=20);
eje.legend(['temperatura'], loc='lower right', fontsize=15);
eje.set_ylabel('Temperatura', fontsize=20);
eje.set_xlabel('Date', fontsize=20);


eje2.plot(df['date'], df['temperatura'], color='b');
eje2.set_title('Temperatura en el tiempo', fontsize=15);
eje2.legend(['temperatura'], loc='best', fontsize=8);
eje2.set_ylabel('Temperatura', fontsize=10);
eje2.set_xlabel('Date', fontsize=10);
eje2.grid(True)

# %%
fig = plt.figure(figsize=(15,8))
eje = fig.add_axes([0,0,1,1]);
eje2 = fig.add_axes([0.7,0.65,0.3,0.3])
eje.grid(True)
eje.plot(df['date'], df['temperatura'], color='g');
eje.set_xlim(datetime.datetime(2014,5,1),datetime.datetime(2014,6,1))
eje.set_title('Temperatura en Mayo 2014', fontsize=25, pad=20);
eje.legend(['temperatura'], loc='lower right', fontsize=15);
eje.set_ylabel('Temperatura', fontsize=20);
eje.set_xlabel('Date', fontsize=20);


eje2.plot(df['date'], df['temperatura'], color='b');
eje2.set_xlim(datetime.datetime(2014,1,1),datetime.datetime(2015,1,1))
eje2.set_title('Temperatura en el tiempo', fontsize=15);
eje2.legend(['temperatura'], loc='best', fontsize=8);
eje2.set_ylabel('Temperatura', fontsize=10);
eje2.set_xlabel('Date', fontsize=10);
eje2.grid(True)

# %%
fig = plt.figure(figsize=(15,8))
eje = fig.add_axes([0,0,1,1]);
eje2 = fig.add_axes([0.7,0.65,0.3,0.3])
eje.grid(True)
eje.plot(df['date'], df['temperatura'], color='g');
eje.set_xlim(datetime.datetime(2014,5,1),datetime.datetime(2014,6,1))
eje.set_ylim(270,320)
eje.set_title('Temperatura en Mayo 2014', fontsize=25, pad=20);
eje.legend(['temperatura'], loc='lower right', fontsize=15);
eje.set_ylabel('Temperatura', fontsize=20);
eje.set_xlabel('Date', fontsize=20);

azul_izquierda = df['date'] < datetime.datetime(2014,5,1)
azul_derecha = df['date'] > datetime.datetime(2014,6,1)


eje2.plot(df['date'], df['temperatura'], color='g');
eje2.plot(df[azul_izquierda]['date'], df[azul_izquierda]['temperatura'], color='b')
eje2.plot(df[azul_derecha]['date'], df[azul_derecha]['temperatura'], color='b')
eje2.set_xlim(datetime.datetime(2014,1,1),datetime.datetime(2015,1,1))
eje2.set_title('Temperatura en 2014', fontsize=15);
eje2.legend(['temperatura'], loc='best', fontsize=8);
eje2.set_ylabel('Temperatura', fontsize=10);
eje2.set_xlabel('Date', fontsize=10);
eje2.grid(True)

# %% [markdown]
# En esta aula, aprendimos:
#
# Cambiar el grosor de la línea;
#
# Agregar un estilo a las líneas;
#
# Seleccionar sólo una parte de los datos para la visualización;
#
# Agregar marcadores;
#
# Agregar cuadrícula a la visualización;
#
# Agregar más de un eje en la misma vista;
#
# Mover el eje y;
#
# Realizar gráficos con más de un colo
